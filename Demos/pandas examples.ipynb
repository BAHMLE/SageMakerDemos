# %%
print("test")
# Out:
# test

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/denisvrdoljak/TXU-Python-Feb2019/master/13-MachineLearningDemo/field_names.txt',header=None).values
# Out:
# array([['ID'],
#        ['diagnosis'],
#        ['radius_mean'],
#        ['radius_sd_error'],
#        ['radius_worst'],
#        ['texture_mean'],
#        ['texture_sd_error'],
#        ['texture_worst'],
#        ['perimeter_mean'],
#        ['perimeter_sd_error'],
#        ['perimeter_worst'],
#        ['area_mean'],
#        ['area_sd_error'],
#        ['area_worst'],
#        ['smoothness_mean'],
#        ['smoothness_sd_error'],
#        ['smoothness_worst'],
#        ['compactness_mean'],
#        ['compactness_sd_error'],
#        ['compactness_worst'],
#        ['concavity_mean'],
#        ['concavity_sd_error'],
#        ['concavity_worst'],
#        ['concave_points_mean'],
#        ['concave_points_sd_error'],
#        ['concave_points_worst'],
#        ['symmetry_mean'],
#        ['symmetry_sd_error'],
#        ['symmetry_worst'],
#        ['fractal_dimension_mean'],
#        ['fractal_dimension_sd_error'],
#        ['fractal_dimension_worst']], dtype=object)

# %%
list(pd.read_csv('https://raw.githubusercontent.com/denisvrdoljak/TXU-Python-Feb2019/master/13-MachineLearningDemo/field_names.txt',header=None)[0])
# Out:
# ['ID',
#  'diagnosis',
#  'radius_mean',
#  'radius_sd_error',
#  'radius_worst',
#  'texture_mean',
#  'texture_sd_error',
#  'texture_worst',
#  'perimeter_mean',
#  'perimeter_sd_error',
#  'perimeter_worst',
#  'area_mean',
#  'area_sd_error',
#  'area_worst',
#  'smoothness_mean',
#  'smoothness_sd_error',
#  'smoothness_worst',
#  'compactness_mean',
#  'compactness_sd_error',
#  'compactness_worst',
#  'concavity_mean',
#  'concavity_sd_error',
#  'concavity_worst',
#  'concave_points_mean',
#  'concave_points_sd_error',
#  'concave_points_worst',
#  'symmetry_mean',
#  'symmetry_sd_error',
#  'symmetry_worst',
#  'fractal_dimension_mean',
#  'fractal_dimension_sd_error',
#  'fractal_dimension_worst']

# %%
pd.read_csv('https://raw.githubusercontent.com/denisvrdoljak/TXU-Python-Feb2019/master/13-MachineLearningDemo/breast-cancer.csv',
            header=None)
# Out:
#            0  1      2      3       4       5        6        7        8   \
# 0      842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 1      842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 2    84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3    84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4    84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# ..        ... ..    ...    ...     ...     ...      ...      ...      ...
# 564    926424  M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390
# 565    926682  M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400
# 566    926954  M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251
# 567    927241  M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140
# 568     92751  B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000
#
#           9   ...      22     23      24      25       26       27      28  \
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/denisvrdoljak/TXU-Python-Feb2019/master/13-MachineLearningDemo/breast-cancer.csv',header=None)
df.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
columns = list(pd.read_csv('https://raw.githubusercontent.com/denisvrdoljak/TXU-Python-Feb2019/master/13-MachineLearningDemo/field_names.txt',header=None)[0])
df.columns = columns
df.head()
# Out:
#          ID diagnosis  radius_mean  radius_sd_error  radius_worst  \
# 0    842302         M        17.99            10.38        122.80
# 1    842517         M        20.57            17.77        132.90
# 2  84300903         M        19.69            21.25        130.00
# 3  84348301         M        11.42            20.38         77.58
# 4  84358402         M        20.29            14.34        135.10
#
#    texture_mean  texture_sd_error  texture_worst  perimeter_mean  \
# 0        1001.0           0.11840        0.27760          0.3001
# 1        1326.0           0.08474        0.07864          0.0869
# 2        1203.0           0.10960        0.15990          0.1974
# 3         386.1           0.14250        0.28390          0.2414
# 4        1297.0           0.10030        0.13280          0.1980
#
#    perimeter_sd_error  ...  concavity_worst  concave_points_mean  \
# 0             0.14710  ...            25.38                17.33
# ...

# %%
df.loc[:,['diagnosis']]
# Out:
#     diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
type(df.loc[:,['diagnosis']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['diagnosis']]
# Out:
#     diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['ID', 'diagnosis', 'radius_mean', 'radius_sd_error', 'radius_worst',
#        'texture_mean', 'texture_sd_error', 'texture_worst', 'perimeter_mean',
#        'perimeter_sd_error', 'perimeter_worst', 'area_mean', 'area_sd_error',
#        'area_worst', 'smoothness_mean', 'smoothness_sd_error',
#        'smoothness_worst', 'compactness_mean', 'compactness_sd_error',
#        'compactness_worst', 'concavity_mean', 'concavity_sd_error',
#        'concavity_worst', 'concave_points_mean', 'concave_points_sd_error',
#        'concave_points_worst', 'symmetry_mean', 'symmetry_sd_error',
#        'symmetry_worst', 'fractal_dimension_mean',
#        'fractal_dimension_sd_error', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df['diagnosis'].index
# Out:
# RangeIndex(start=0, stop=569, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=569, step=1)

# %%
df['radius_sd_error'].mean()
# Out:
# 19.28964850615117

# %%
df.mean()
# Out:
# ID                            3.037183e+07
# radius_mean                   1.412729e+01
# radius_sd_error               1.928965e+01
# radius_worst                  9.196903e+01
# texture_mean                  6.548891e+02
# texture_sd_error              9.636028e-02
# texture_worst                 1.043410e-01
# perimeter_mean                8.879932e-02
# perimeter_sd_error            4.891915e-02
# perimeter_worst               1.811619e-01
# area_mean                     6.279761e-02
# area_sd_error                 4.051721e-01
# area_worst                    1.216853e+00
# smoothness_mean               2.866059e+00
# smoothness_sd_error           4.033708e+01
# smoothness_worst              7.040979e-03
# compactness_mean              2.547814e-02
# compactness_sd_error          3.189372e-02
# compactness_worst             1.179614e-02
# concavity_mean                2.054230e-02
# concavity_sd_error            3.794904e-03
# concavity_worst               1.626919e+01
# ...

# %%
type(df.mean())
# Out:
# pandas.core.series.Series

# %%
df.mean().index
# Out:
# Index(['ID', 'radius_mean', 'radius_sd_error', 'radius_worst', 'texture_mean',
#        'texture_sd_error', 'texture_worst', 'perimeter_mean',
#        'perimeter_sd_error', 'perimeter_worst', 'area_mean', 'area_sd_error',
#        'area_worst', 'smoothness_mean', 'smoothness_sd_error',
#        'smoothness_worst', 'compactness_mean', 'compactness_sd_error',
#        'compactness_worst', 'concavity_mean', 'concavity_sd_error',
#        'concavity_worst', 'concave_points_mean', 'concave_points_sd_error',
#        'concave_points_worst', 'symmetry_mean', 'symmetry_sd_error',
#        'symmetry_worst', 'fractal_dimension_mean',
#        'fractal_dimension_sd_error', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.mean()['radius_mean']
# Out:
# 14.127291739894563

# %%
df.dtypes
# Out:
# ID                              int64
# diagnosis                      object
# radius_mean                   float64
# radius_sd_error               float64
# radius_worst                  float64
# texture_mean                  float64
# texture_sd_error              float64
# texture_worst                 float64
# perimeter_mean                float64
# perimeter_sd_error            float64
# perimeter_worst               float64
# area_mean                     float64
# area_sd_error                 float64
# area_worst                    float64
# smoothness_mean               float64
# smoothness_sd_error           float64
# smoothness_worst              float64
# compactness_mean              float64
# compactness_sd_error          float64
# compactness_worst             float64
# concavity_mean                float64
# concavity_sd_error            float64
# concavity_worst               float64
# concave_points_mean           float64
# concave_points_sd_error       float64
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.drop('ID',axis=1)
# Out:
#     diagnosis  radius_mean  radius_sd_error  radius_worst  texture_mean  \
# 0           M        17.99            10.38        122.80        1001.0
# 1           M        20.57            17.77        132.90        1326.0
# 2           M        19.69            21.25        130.00        1203.0
# 3           M        11.42            20.38         77.58         386.1
# 4           M        20.29            14.34        135.10        1297.0
# ..        ...          ...              ...           ...           ...
# 564         M        21.56            22.39        142.00        1479.0
# 565         M        20.13            28.25        131.20        1261.0
# 566         M        16.60            28.08        108.30         858.1
# 567         M        20.60            29.33        140.10        1265.0
# 568         B         7.76            24.54         47.92         181.0
#
#      texture_sd_error  texture_worst  perimeter_mean  perimeter_sd_error  \
# ...

# %%
df
# Out:
#            ID diagnosis  radius_mean  radius_sd_error  radius_worst  \
# 0      842302         M        17.99            10.38        122.80
# 1      842517         M        20.57            17.77        132.90
# 2    84300903         M        19.69            21.25        130.00
# 3    84348301         M        11.42            20.38         77.58
# 4    84358402         M        20.29            14.34        135.10
# ..        ...       ...          ...              ...           ...
# 564    926424         M        21.56            22.39        142.00
# 565    926682         M        20.13            28.25        131.20
# 566    926954         M        16.60            28.08        108.30
# 567    927241         M        20.60            29.33        140.10
# 568     92751         B         7.76            24.54         47.92
#
#      texture_mean  texture_sd_error  texture_worst  perimeter_mean  \
# 0          1001.0           0.11840        0.27760         0.30010
# ...

# %%
df['diagnosis'] == 'M'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 564     True
# 565     True
# 566     True
# 567     True
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
df['bool_diagnosis'] = df['diagnosis'] == 'M'

# %%
df.head()
# Out:
#          ID diagnosis  radius_mean  radius_sd_error  radius_worst  \
# 0    842302         M        17.99            10.38        122.80
# 1    842517         M        20.57            17.77        132.90
# 2  84300903         M        19.69            21.25        130.00
# 3  84348301         M        11.42            20.38         77.58
# 4  84358402         M        20.29            14.34        135.10
#
#    texture_mean  texture_sd_error  texture_worst  perimeter_mean  \
# 0        1001.0           0.11840        0.27760          0.3001
# 1        1326.0           0.08474        0.07864          0.0869
# 2        1203.0           0.10960        0.15990          0.1974
# 3         386.1           0.14250        0.28390          0.2414
# 4        1297.0           0.10030        0.13280          0.1980
#
#    perimeter_sd_error  ...  concave_points_mean  concave_points_sd_error  \
# 0             0.14710  ...                17.33                   184.60
# ...

# %%
df.describe().T
# Out:
#                             count          mean           std          min  \
# ID                          569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean                 569.0  1.412729e+01  3.524049e+00     6.981000
# radius_sd_error             569.0  1.928965e+01  4.301036e+00     9.710000
# radius_worst                569.0  9.196903e+01  2.429898e+01    43.790000
# texture_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# texture_sd_error            569.0  9.636028e-02  1.406413e-02     0.052630
# texture_worst               569.0  1.043410e-01  5.281276e-02     0.019380
# perimeter_mean              569.0  8.879932e-02  7.971981e-02     0.000000
# perimeter_sd_error          569.0  4.891915e-02  3.880284e-02     0.000000
# perimeter_worst             569.0  1.811619e-01  2.741428e-02     0.106000
# area_mean                   569.0  6.279761e-02  7.060363e-03     0.049960
# ...

# %%
df['diagnosis'] == 'M'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 564     True
# 565     True
# 566     True
# 567     True
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
df[df['diagnosis'] == 'M']
# Out:
#            ID diagnosis  radius_mean  radius_sd_error  radius_worst  \
# 0      842302         M        17.99            10.38        122.80
# 1      842517         M        20.57            17.77        132.90
# 2    84300903         M        19.69            21.25        130.00
# 3    84348301         M        11.42            20.38         77.58
# 4    84358402         M        20.29            14.34        135.10
# ..        ...       ...          ...              ...           ...
# 563    926125         M        20.92            25.09        143.00
# 564    926424         M        21.56            22.39        142.00
# 565    926682         M        20.13            28.25        131.20
# 566    926954         M        16.60            28.08        108.30
# 567    927241         M        20.60            29.33        140.10
#
#      texture_mean  texture_sd_error  texture_worst  perimeter_mean  \
# 0          1001.0           0.11840        0.27760         0.30010
# ...

# %%
df[df['diagnosis'] == 'M'].shape
# Out:
# (212, 33)

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          569 non-null    int64
#  1   diagnosis                   569 non-null    object
#  2   radius_mean                 569 non-null    float64
#  3   radius_sd_error             569 non-null    float64
#  4   radius_worst                569 non-null    float64
#  5   texture_mean                569 non-null    float64
#  6   texture_sd_error            569 non-null    float64
#  7   texture_worst               569 non-null    float64
#  8   perimeter_mean              569 non-null    float64
#  9   perimeter_sd_error          569 non-null    float64
#  10  perimeter_worst             569 non-null    float64
#  11  area_mean                   569 non-null    float64
#  12  area_sd_error               569 non-null    float64
# ...

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['ID', 'diagnosis', 'radius_mean', 'radius_sd_error', 'radius_worst',
#        'texture_mean', 'texture_sd_error', 'texture_worst', 'perimeter_mean',
#        'perimeter_sd_error', 'perimeter_worst', 'area_mean', 'area_sd_error',
#        'area_worst', 'smoothness_mean', 'smoothness_sd_error',
#        'smoothness_worst', 'compactness_mean', 'compactness_sd_error',
#        'compactness_worst', 'concavity_mean', 'concavity_sd_error',
#        'concavity_worst', 'concave_points_mean', 'concave_points_sd_error',
#        'concave_points_worst', 'symmetry_mean', 'symmetry_sd_error',
#        'symmetry_worst', 'fractal_dimension_mean',
#        'fractal_dimension_sd_error', 'fractal_dimension_worst'],
#       dtype='object')

# %%
sns.pairplot(df[['smoothness_mean','smoothness_worst','smoothness_sd_error','diagnosis']],hue='diagnosis')

# %%
sns.heatmap(df[['smoothness_mean','smoothness_worst','smoothness_sd_error','diagnosis']].corr())

# %%
df['diag'] = df['diagnosis'] == 'M'

# %%
df.corr()['diag']
# Out:
# ID                            0.039769
# radius_mean                   0.730029
# radius_sd_error               0.415185
# radius_worst                  0.742636
# texture_mean                  0.708984
# texture_sd_error              0.358560
# texture_worst                 0.596534
# perimeter_mean                0.696360
# perimeter_sd_error            0.776614
# perimeter_worst               0.330499
# area_mean                    -0.012838
# area_sd_error                 0.567134
# area_worst                   -0.008303
# smoothness_mean               0.556141
# smoothness_sd_error           0.548236
# smoothness_worst             -0.067016
# compactness_mean              0.292999
# compactness_sd_error          0.253730
# compactness_worst             0.408042
# concavity_mean               -0.006522
# concavity_sd_error            0.077972
# concavity_worst               0.776454
# concave_points_mean           0.456903
# concave_points_sd_error       0.782914
# ...

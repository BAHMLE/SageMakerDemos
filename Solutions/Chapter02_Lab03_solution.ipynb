# %% [markdown]
# # LAB: Machine Learning with Linear Learner and Hyperparameter Tuning
#
# NOTE: This notebook should be run in AWS SageMaker python environment.

# %% [markdown]
# Install and import required Libraries

# %%
# If you have an error in creation role, try to upgrade boto3
# %pip install --upgrade boto3
! pip install -U numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.26.97)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.97 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (1.29.97)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (0.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.97->boto3) (1.26.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.97->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.97->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.22.3)
# Collecting numpy
#   Downloading numpy-1.24.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 28.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.3
#     Uninstalling numpy-1.22.3:
#       Successfully uninstalled numpy-1.22.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sparkmagic 0.20.3 requires nest-asyncio==1.5.5, but you have nest-asyncio 1.5.6 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.
# Successfully installed numpy-1.24.2

# %% [markdown]
# Import dependencies

# %%
import pandas as pd
import numpy as np
import boto3
import urllib.request, json, os, sagemaker
from sagemaker import get_execution_role
from time import gmtime, strftime
from sagemaker.predictor import csv_serializer
from sagemaker.tuner import (
    IntegerParameter,
    CategoricalParameter,
    ContinuousParameter,
    HyperparameterTuner,
)
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Get region

# %%
my_region = boto3.session.Session().region_name
prefix = 'sagemaker/MLI-Lab_solution'

print("Region: {}".format(my_region))
# Out:
# Region: us-west-2

# %% [markdown]
# Create boto3 object

# %%
s3 = boto3.resource('s3')

# %% [markdown]
# Create bucket for model artifacts

# %%
bucket_name = 'bah-bucket-sagemaker-course-2023'

# %%
try:
    if  my_region == 'us-east-1':
        if not s3.Bucket(bucket_name).creation_date:
            s3.create_bucket(Bucket=bucket_name)
            print('S3 bucket created successfully')
        else:
            print('Bucket already exists!')
    else: 
        if not s3.Bucket(bucket_name).creation_date:
            s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={'LocationConstraint': my_region})
            print('S3 bucket created successfully')
        else:
            print('Bucket already exists!')
except Exception as e:
    print('S3 error: ', e)
# Out:
# Bucket already exists!

# %% [markdown]
# Read `heart disease classification dataset.csv` dataset

# %%
# This dataset can be found on Kaggle as well: https://www.kaggle.com/datasets/yasserh/breast-cancer-dataset
import os

DATASET = 'heart disease classification dataset.csv'
DATA_FOLDER = 's3://bah-data'

data = pd.read_csv(os.path.join(DATA_FOLDER, DATASET))

# %%
data.head()
# Out:
#    Unnamed: 0  age     sex  cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0           0   63    male   3     145.0  233.0    1        0    150.0      0
# 1           1   37    male   2     130.0  250.0    0        1    187.0      0
# 2           2   41  female   1     130.0  204.0    0        0    172.0      0
# 3           3   56    male   1     120.0  236.0    0        1    178.0      0
# 4           4   57  female   0       NaN  354.0    0        1    163.0      1
#
#    oldpeak  slope  ca  thal target
# 0      2.3      0   0     1    yes
# 1      3.5      0   0     2    yes
# 2      1.4      2   0     2    yes
# 3      0.8      2   0     2    yes
# 4      0.6      2   0     2    yes

# %% [markdown]
# Prepare and preprocess the dataset

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps     True
# chol         True
# fbs         False
# restecg     False
# thalach      True
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
data.dropna(inplace=True)
data = data.reset_index(drop=True)

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# cp            int64
# trestbps    float64
# chol        float64
# fbs           int64
# restecg       int64
# thalach     float64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target       object
# dtype: object

# %%
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     48
# chol        149
# fbs           2
# restecg       3
# thalach      89
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
data['target'].value_counts()
# Out:
# yes    160
# no     133
# Name: target, dtype: int64

# %% [markdown]
# Convert target column into numerical representation using LabelEncoder from sklearn

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
label = le.fit_transform(data['target'])

data.drop('target', axis=1, inplace=True)
data["label"] = label

# %%
data.head()
# Out:
#    age     sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3     145.0  233.0    1        0    150.0      0      2.3
# 1   37    male   2     130.0  250.0    0        1    187.0      0      3.5
# 2   41  female   1     130.0  204.0    0        0    172.0      0      1.4
# 3   56    male   1     120.0  236.0    0        1    178.0      0      0.8
# 4   57    male   0     140.0  192.0    0        1    148.0      0      0.4
#
#    slope  ca  thal  label
# 0      0   0     1      1
# 1      0   0     2      1
# 2      2   0     2      1
# 3      2   0     2      1
# 4      1   0     1      1

# %% [markdown]
# Convert categorical features into one-hot encoding (if there are some)

# %%
from sklearn.preprocessing import OneHotEncoder
one_hot_encoder = OneHotEncoder()

output = one_hot_encoder.fit_transform(data['sex'].values.reshape(-1, 1)).toarray()

# %%
sex_one_hot_encoded = pd.DataFrame(output).rename(columns={0: 'male', 1: 'female'})

# %%
data = pd.concat([data, sex_one_hot_encoded], axis=1)

# %%
data.drop('sex', axis=1, inplace=True)

# %%
data.head(5)
# Out:
#    age  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63   3     145.0  233.0    1        0    150.0      0      2.3      0   0
# 1   37   2     130.0  250.0    0        1    187.0      0      3.5      0   0
# 2   41   1     130.0  204.0    0        0    172.0      0      1.4      2   0
# 3   56   1     120.0  236.0    0        1    178.0      0      0.8      2   0
# 4   57   0     140.0  192.0    0        1    148.0      0      0.4      1   0
#
#    thal  label  male  female
# 0     1      1   0.0     1.0
# 1     2      1   0.0     1.0
# 2     2      1   1.0     0.0
# 3     2      1   0.0     1.0
# 4     1      1   0.0     1.0

# %% [markdown]
# Upload train/validation data to s3

# %%
train_data, validation_data, test_data = np.split(
    data.sample(frac=1, random_state=1729),
    [int(0.7 * len(data)), int(0.9 * len(data))],
)

print(train_data.shape, test_data.shape, validation_data.shape)
# Out:
# (205, 15) (30, 15) (58, 15)

# %%
label_column = train_data['label']
train_data = train_data.drop(['label'], axis=1)
train_data = pd.concat([label_column, train_data], axis=1)

train_data.to_csv('train.csv', index=False, header=False)

boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
s3_input_train = sagemaker.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='text/csv')

# %%
train_data.head()
# Out:
#      label  age  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 178      0   50   0     150.0  243.0    0        0    128.0      0      2.6
# 26       1   65   2     140.0  417.0    1        0    157.0      0      0.8
# 196      0   58   0     150.0  270.0    0        0    111.0      1      0.8
# 248      0   45   0     142.0  309.0    0        0    147.0      1      0.0
# 107      1   57   2     150.0  126.0    1        1    173.0      0      0.2
#
#      slope  ca  thal  male  female
# 178      1   0     3   0.0     1.0
# 26       2   1     2   1.0     0.0
# 196      2   0     3   0.0     1.0
# 248      1   3     3   0.0     1.0
# 107      2   1     3   0.0     1.0

# %%
label_column = validation_data['label']
validation_data = validation_data.drop(['label'], axis=1)
validation_data = pd.concat([label_column, validation_data], axis=1)

validation_data.to_csv('validation.csv', index=False, header=False)

boto3.Session().resource("s3").Bucket(bucket_name).Object(os.path.join(prefix, "validation/validation.csv")).upload_file("validation.csv")

s3_input_validation = sagemaker.TrainingInput(s3_data='s3://{}/{}/validation'.format(bucket_name, prefix), content_type='text/csv')

# %%
validation_data.head()
# Out:
#      label  age  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 118      1   41   2     112.0  268.0    0        0    172.0      1      0.0
# 234      0   59   0     174.0  249.0    0        1    143.0      1      0.0
# 59       1   52   3     118.0  186.0    0        0    190.0      0      0.0
# 288      0   63   0     124.0  197.0    0        1    136.0      1      0.0
# 198      0   62   0     160.0  164.0    0        0    145.0      0      6.2
#
#      slope  ca  thal  male  female
# 118      2   0     2   1.0     0.0
# 234      1   0     2   1.0     0.0
# 59       1   0     1   0.0     1.0
# 288      1   0     2   1.0     0.0
# 198      0   3     3   1.0     0.0

# %% [markdown]
# Train the model (use any built-in algorithm)

# %% [markdown]
# Create SageMaker session

# %%
sess = sagemaker.Session()

# %% [markdown]
# Define IAM role

# %%
role = get_execution_role()

# %% [markdown]
# Specify container

# %%
linear_learner_container = sagemaker.image_uris.retrieve("linear-learner", my_region)

# %% [markdown]
# Create Estimator

# %%
linear = sagemaker.estimator.Estimator(
    linear_learner_container,
    role,
    train_instance_count=1,
    train_instance_type="ml.m4.xlarge",
    output_path='s3://{}/{}/output'.format(bucket_name, prefix),
    sagemaker_session=sess,
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# Set initial hyperparameters

# %%
linear.set_hyperparameters(
                           predictor_type="binary_classifier",
                           mini_batch_size=30)

# %% [markdown]
# Fit the model

# %%
linear.fit({"train": s3_input_train})
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2023-03-17-21-59-43-296
# 2023-03-17 21:59:43 Starting - Starting the training job...
# 2023-03-17 22:00:11 Starting - Preparing the instances for training......
# 2023-03-17 22:01:13 Downloading - Downloading input data...
# 2023-03-17 22:01:38 Training - Downloading the training image.........
# 2023-03-17 22:02:54 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/17/2023 22:03:11 INFO 140685723006784] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [03/17/2023 22:03:11 INFO 140685723006784] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'mini_batch_size': '30', 'predictor_type': 'binary_classifier'}
# [03/17/2023 22:03:11 INFO 140685723006784] Final configuration: {'mini_batch_size': '30', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [03/17/2023 22:03:14 WARNING 140685723006784] Loggers have already been setup.
# [03/17/2023 22:03:14 INFO 140685723006784] Final configuration: {'mini_batch_size': '30', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [03/17/2023 22:03:14 WARNING 140685723006784] Loggers have already been setup.
# Process 7 is a worker.
# [03/17/2023 22:03:14 INFO 140685723006784] Using default worker.
# [03/17/2023 22:03:14 INFO 140685723006784] Checkpoint loading and saving are disabled.
# [03/17/2023 22:03:14 INFO 140685723006784] Create Store: local
# [03/17/2023 22:03:14 INFO 140685723006784] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7ff362102f10>
# [03/17/2023 22:03:14 INFO 140685723006784] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [ 9.500505    1.0379229  18.420784   55.539433    0.36243352  0.518783
#  22.73396     0.46294817  1.1241342   0.6377042   1.0466878   0.60987246
#   0.4714045   0.47140452]
# <NDArray 14 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [5.4961113e+01 1.0222223e+00 1.3238333e+02 2.4773334e+02 1.5555556e-01
#  5.5555558e-01 1.4997778e+02 3.1111112e-01 1.0694444e+00 1.4000001e+00
#  7.3333335e-01 2.3166668e+00 3.3333337e-01 6.6666681e-01]
# <NDArray 14 @cpu(0)>}
# [03/17/2023 22:03:14 INFO 140685723006784] nvidia-smi: took 0.032 seconds to run.
# [03/17/2023 22:03:14 INFO 140685723006784] nvidia-smi identified 0 GPUs.
# [03/17/2023 22:03:14 INFO 140685723006784] Number of GPUs being used: 0
# #metrics {"StartTime": 1679090594.7453997, "EndTime": 1679090594.7454407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 235.0, "count": 1, "min": 235, "max": 235}, "Total Batches Seen": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Max Records Seen Between Resets": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Max Batches Seen Between Resets": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1679090594.9827788, "EndTime": 1679090594.9828515, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.671352661980523, "count": 1, "min": 0.671352661980523, "max": 0.671352661980523}}}
# #metrics {"StartTime": 1679090594.98294, "EndTime": 1679090594.982959, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6442475001017253, "count": 1, "min": 0.6442475001017253, "max": 0.6442475001017253}}}
# #metrics {"StartTime": 1679090594.983026, "EndTime": 1679090594.9830437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6581400659349229, "count": 1, "min": 0.6581400659349229, "max": 0.6581400659349229}}}
# #metrics {"StartTime": 1679090594.9831014, "EndTime": 1679090594.983113, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6195290035671658, "count": 1, "min": 0.6195290035671658, "max": 0.6195290035671658}}}
# #metrics {"StartTime": 1679090594.983165, "EndTime": 1679090594.9831798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5215811146630182, "count": 1, "min": 0.5215811146630182, "max": 0.5215811146630182}}}
# #metrics {"StartTime": 1679090594.9832327, "EndTime": 1679090594.9832497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5329362975226508, "count": 1, "min": 0.5329362975226508, "max": 0.5329362975226508}}}
# #metrics {"StartTime": 1679090594.98331, "EndTime": 1679090594.9833267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5251362376742893, "count": 1, "min": 0.5251362376742893, "max": 0.5251362376742893}}}
# #metrics {"StartTime": 1679090594.983388, "EndTime": 1679090594.9834049, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5141791078779433, "count": 1, "min": 0.5141791078779433, "max": 0.5141791078779433}}}
# #metrics {"StartTime": 1679090594.9834647, "EndTime": 1679090594.9834824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6863734669155545, "count": 1, "min": 0.6863734669155545, "max": 0.6863734669155545}}}
# #metrics {"StartTime": 1679090594.9835298, "EndTime": 1679090594.9835458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6555413987901476, "count": 1, "min": 0.6555413987901476, "max": 0.6555413987901476}}}
# #metrics {"StartTime": 1679090594.9835932, "EndTime": 1679090594.983607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6888718287150065, "count": 1, "min": 0.6888718287150065, "max": 0.6888718287150065}}}
# #metrics {"StartTime": 1679090594.9836655, "EndTime": 1679090594.9836817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.696489323510064, "count": 1, "min": 0.696489323510064, "max": 0.696489323510064}}}
# #metrics {"StartTime": 1679090594.9837384, "EndTime": 1679090594.983754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5170782036251492, "count": 1, "min": 0.5170782036251492, "max": 0.5170782036251492}}}
# #metrics {"StartTime": 1679090594.9838092, "EndTime": 1679090594.983823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5306787808736165, "count": 1, "min": 0.5306787808736165, "max": 0.5306787808736165}}}
# #metrics {"StartTime": 1679090594.9838774, "EndTime": 1679090594.9838939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5388137075636122, "count": 1, "min": 0.5388137075636122, "max": 0.5388137075636122}}}
# #metrics {"StartTime": 1679090594.9839485, "EndTime": 1679090594.9839642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.514446825451321, "count": 1, "min": 0.514446825451321, "max": 0.514446825451321}}}
# #metrics {"StartTime": 1679090594.9840553, "EndTime": 1679090594.984073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6693347401089138, "count": 1, "min": 0.6693347401089138, "max": 0.6693347401089138}}}
# #metrics {"StartTime": 1679090594.9841285, "EndTime": 1679090594.9841452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6576702859666612, "count": 1, "min": 0.6576702859666612, "max": 0.6576702859666612}}}
# #metrics {"StartTime": 1679090594.9842072, "EndTime": 1679090594.9842231, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6542474534776476, "count": 1, "min": 0.6542474534776476, "max": 0.6542474534776476}}}
# #metrics {"StartTime": 1679090594.9842815, "EndTime": 1679090594.9842982, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6891177389356825, "count": 1, "min": 0.6891177389356825, "max": 0.6891177389356825}}}
# #metrics {"StartTime": 1679090594.9843452, "EndTime": 1679090594.9843564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5645543522304959, "count": 1, "min": 0.5645543522304959, "max": 0.5645543522304959}}}
# #metrics {"StartTime": 1679090594.9844012, "EndTime": 1679090594.9844105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5447291586134169, "count": 1, "min": 0.5447291586134169, "max": 0.5447291586134169}}}
# #metrics {"StartTime": 1679090594.9844575, "EndTime": 1679090594.984475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5717565112643772, "count": 1, "min": 0.5717565112643772, "max": 0.5717565112643772}}}
# #metrics {"StartTime": 1679090594.98452, "EndTime": 1679090594.9845357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5629307111104329, "count": 1, "min": 0.5629307111104329, "max": 0.5629307111104329}}}
# #metrics {"StartTime": 1679090594.9845908, "EndTime": 1679090594.9846084, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7184135225084093, "count": 1, "min": 0.7184135225084093, "max": 0.7184135225084093}}}
# #metrics {"StartTime": 1679090594.984671, "EndTime": 1679090594.984689, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6763780170016819, "count": 1, "min": 0.6763780170016819, "max": 0.6763780170016819}}}
# #metrics {"StartTime": 1679090594.9847522, "EndTime": 1679090594.9847698, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6921777089436849, "count": 1, "min": 0.6921777089436849, "max": 0.6921777089436849}}}
# #metrics {"StartTime": 1679090594.9848335, "EndTime": 1679090594.9848514, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6715485042995877, "count": 1, "min": 0.6715485042995877, "max": 0.6715485042995877}}}
# #metrics {"StartTime": 1679090594.9849067, "EndTime": 1679090594.9849231, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.723863485124376, "count": 1, "min": 0.723863485124376, "max": 0.723863485124376}}}
# #metrics {"StartTime": 1679090594.9849794, "EndTime": 1679090594.984996, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7089821073744033, "count": 1, "min": 0.7089821073744033, "max": 0.7089821073744033}}}
# #metrics {"StartTime": 1679090594.9850414, "EndTime": 1679090594.9850569, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7503578927781847, "count": 1, "min": 0.7503578927781847, "max": 0.7503578927781847}}}
# #metrics {"StartTime": 1679090594.9851196, "EndTime": 1679090594.9851372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7267247200012207, "count": 1, "min": 0.7267247200012207, "max": 0.7267247200012207}}}
# [03/17/2023 22:03:14 INFO 140685723006784] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.671352661980523
# [03/17/2023 22:03:14 INFO 140685723006784] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.5141791078779433
# [03/17/2023 22:03:14 INFO 140685723006784] Epoch 0: Loss improved. Updating best model
# [03/17/2023 22:03:14 INFO 140685723006784] Saving model for epoch: 0
# [03/17/2023 22:03:14 INFO 140685723006784] Saved checkpoint to "/tmp/tmpbs957njl/mx-mod-0000.params"
# [03/17/2023 22:03:14 INFO 140685723006784] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1679090594.745719, "EndTime": 1679090594.9957886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 440.0, "count": 1, "min": 440, "max": 440}, "Total Batches Seen": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Max Records Seen Between Resets": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Max Batches Seen Between Resets": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Number of Batches Since Last Reset": {"sum": 7.0, "count": 1, "min": 7, "max": 7}}}
# [03/17/2023 22:03:14 INFO 140685723006784] #throughput_metric: host=algo-1, train throughput=819.3584696735363 records/second
# #metrics {"StartTime": 1679090595.225262, "EndTime": 1679090595.2253177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6172691027323405, "count": 1, "min": 0.6172691027323405, "max": 0.6172691027323405}}}
# #metrics {"StartTime": 1679090595.2253995, "EndTime": 1679090595.2254176, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5947454240587022, "count": 1, "min": 0.5947454240587022, "max": 0.5947454240587022}}}
# #metrics {"StartTime": 1679090595.2254717, "EndTime": 1679090595.225488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.604681216345893, "count": 1, "min": 0.604681216345893, "max": 0.604681216345893}}}
# #metrics {"StartTime": 1679090595.2255685, "EndTime": 1679090595.225586, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5711407661437988, "count": 1, "min": 0.5711407661437988, "max": 0.5711407661437988}}}
# #metrics {"StartTime": 1679090595.225641, "EndTime": 1679090595.225658, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35613921218448213, "count": 1, "min": 0.35613921218448213, "max": 0.35613921218448213}}}
# #metrics {"StartTime": 1679090595.2257178, "EndTime": 1679090595.2257328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3620192872153388, "count": 1, "min": 0.3620192872153388, "max": 0.3620192872153388}}}
# #metrics {"StartTime": 1679090595.2257833, "EndTime": 1679090595.225798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3604999171362983, "count": 1, "min": 0.3604999171362983, "max": 0.3604999171362983}}}
# #metrics {"StartTime": 1679090595.2258456, "EndTime": 1679090595.2258594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35813658237457274, "count": 1, "min": 0.35813658237457274, "max": 0.35813658237457274}}}
# #metrics {"StartTime": 1679090595.2259126, "EndTime": 1679090595.2259278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6306539217631022, "count": 1, "min": 0.6306539217631022, "max": 0.6306539217631022}}}
# #metrics {"StartTime": 1679090595.2259867, "EndTime": 1679090595.2260041, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.602941714392768, "count": 1, "min": 0.602941714392768, "max": 0.602941714392768}}}
# #metrics {"StartTime": 1679090595.2260478, "EndTime": 1679090595.2260623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6327884568108453, "count": 1, "min": 0.6327884568108453, "max": 0.6327884568108453}}}
# #metrics {"StartTime": 1679090595.2261162, "EndTime": 1679090595.226132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6408478842841254, "count": 1, "min": 0.6408478842841254, "max": 0.6408478842841254}}}
# #metrics {"StartTime": 1679090595.2261899, "EndTime": 1679090595.2262063, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35310774909125436, "count": 1, "min": 0.35310774909125436, "max": 0.35310774909125436}}}
# #metrics {"StartTime": 1679090595.226255, "EndTime": 1679090595.2262697, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35844969219631617, "count": 1, "min": 0.35844969219631617, "max": 0.35844969219631617}}}
# #metrics {"StartTime": 1679090595.2263498, "EndTime": 1679090595.2263665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.359891864988539, "count": 1, "min": 0.359891864988539, "max": 0.359891864988539}}}
# #metrics {"StartTime": 1679090595.2264168, "EndTime": 1679090595.2264283, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35368312199910484, "count": 1, "min": 0.35368312199910484, "max": 0.35368312199910484}}}
# #metrics {"StartTime": 1679090595.2264845, "EndTime": 1679090595.226499, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6190146340264214, "count": 1, "min": 0.6190146340264214, "max": 0.6190146340264214}}}
# #metrics {"StartTime": 1679090595.2265446, "EndTime": 1679090595.2265594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6077757093641493, "count": 1, "min": 0.6077757093641493, "max": 0.6077757093641493}}}
# #metrics {"StartTime": 1679090595.2265997, "EndTime": 1679090595.2266142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6057703759935167, "count": 1, "min": 0.6057703759935167, "max": 0.6057703759935167}}}
# #metrics {"StartTime": 1679090595.2266648, "EndTime": 1679090595.2266808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6318848186069065, "count": 1, "min": 0.6318848186069065, "max": 0.6318848186069065}}}
# #metrics {"StartTime": 1679090595.2267337, "EndTime": 1679090595.2267442, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5316201421949599, "count": 1, "min": 0.5316201421949599, "max": 0.5316201421949599}}}
# #metrics {"StartTime": 1679090595.2267804, "EndTime": 1679090595.226795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.551347737842136, "count": 1, "min": 0.551347737842136, "max": 0.551347737842136}}}
# #metrics {"StartTime": 1679090595.226834, "EndTime": 1679090595.2268486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5235734144846599, "count": 1, "min": 0.5235734144846599, "max": 0.5235734144846599}}}
# #metrics {"StartTime": 1679090595.2269025, "EndTime": 1679090595.2269185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5352330101860894, "count": 1, "min": 0.5352330101860894, "max": 0.5352330101860894}}}
# #metrics {"StartTime": 1679090595.2269597, "EndTime": 1679090595.2269745, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6865832540724013, "count": 1, "min": 0.6865832540724013, "max": 0.6865832540724013}}}
# #metrics {"StartTime": 1679090595.2270243, "EndTime": 1679090595.2270398, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6699004173278809, "count": 1, "min": 0.6699004173278809, "max": 0.6699004173278809}}}
# #metrics {"StartTime": 1679090595.227101, "EndTime": 1679090595.227117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6796806865268283, "count": 1, "min": 0.6796806865268283, "max": 0.6796806865268283}}}
# #metrics {"StartTime": 1679090595.2271712, "EndTime": 1679090595.2271874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6736453586154514, "count": 1, "min": 0.6736453586154514, "max": 0.6736453586154514}}}
# #metrics {"StartTime": 1679090595.227239, "EndTime": 1679090595.2272499, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7061592737833658, "count": 1, "min": 0.7061592737833658, "max": 0.7061592737833658}}}
# #metrics {"StartTime": 1679090595.2273047, "EndTime": 1679090595.2273219, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7083613289727105, "count": 1, "min": 0.7083613289727105, "max": 0.7083613289727105}}}
# #metrics {"StartTime": 1679090595.2273846, "EndTime": 1679090595.2274017, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6829743491278755, "count": 1, "min": 0.6829743491278755, "max": 0.6829743491278755}}}
# #metrics {"StartTime": 1679090595.2274673, "EndTime": 1679090595.2274847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7138755480448405, "count": 1, "min": 0.7138755480448405, "max": 0.7138755480448405}}}
# [03/17/2023 22:03:15 INFO 140685723006784] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.6172691027323405
# [03/17/2023 22:03:15 INFO 140685723006784] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.35310774909125436
# [03/17/2023 22:03:15 INFO 140685723006784] Epoch 1: Loss improved. Updating best model
# [03/17/2023 22:03:15 INFO 140685723006784] Saving model for epoch: 1
# [03/17/2023 22:03:15 INFO 140685723006784] Saved checkpoint to "/tmp/tmplec0k6mr/mx-mod-0000.params"
# [03/17/2023 22:03:15 INFO 140685723006784] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1679090594.996123, "EndTime": 1679090595.2368503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 645.0, "count": 1, "min": 645, "max": 645}, "Total Batches Seen": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Max Records Seen Between Resets": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Max Batches Seen Between Resets": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Number of Batches Since Last Reset": {"sum": 7.0, "count": 1, "min": 7, "max": 7}}}
# [03/17/2023 22:03:15 INFO 140685723006784] #throughput_metric: host=algo-1, train throughput=851.1042459577037 records/second
# #metrics {"StartTime": 1679090595.5112746, "EndTime": 1679090595.5113666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5747297551896837, "count": 1, "min": 0.5747297551896837, "max": 0.5747297551896837}}}
# #metrics {"StartTime": 1679090595.5114782, "EndTime": 1679090595.511499, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5561437235938178, "count": 1, "min": 0.5561437235938178, "max": 0.5561437235938178}}}
# #metrics {"StartTime": 1679090595.5115612, "EndTime": 1679090595.5115786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.562837553024292, "count": 1, "min": 0.562837553024292, "max": 0.562837553024292}}}
# #metrics {"StartTime": 1679090595.5116422, "EndTime": 1679090595.5116608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5338401794433594, "count": 1, "min": 0.5338401794433594, "max": 0.5338401794433594}}}
# #metrics {"StartTime": 1679090595.5117264, "EndTime": 1679090595.5117435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3449380477269491, "count": 1, "min": 0.3449380477269491, "max": 0.3449380477269491}}}
# #metrics {"StartTime": 1679090595.5118, "EndTime": 1679090595.5118167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.34627447923024496, "count": 1, "min": 0.34627447923024496, "max": 0.34627447923024496}}}
# #metrics {"StartTime": 1679090595.5118787, "EndTime": 1679090595.511897, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3444885280397203, "count": 1, "min": 0.3444885280397203, "max": 0.3444885280397203}}}
# #metrics {"StartTime": 1679090595.511967, "EndTime": 1679090595.5119846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.34475340843200686, "count": 1, "min": 0.34475340843200686, "max": 0.34475340843200686}}}
# #metrics {"StartTime": 1679090595.5120838, "EndTime": 1679090595.5121026, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5867577128940158, "count": 1, "min": 0.5867577128940158, "max": 0.5867577128940158}}}
# #metrics {"StartTime": 1679090595.51217, "EndTime": 1679090595.5121894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5616866164737278, "count": 1, "min": 0.5616866164737278, "max": 0.5616866164737278}}}
# #metrics {"StartTime": 1679090595.512257, "EndTime": 1679090595.5122752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5883043713039822, "count": 1, "min": 0.5883043713039822, "max": 0.5883043713039822}}}
# #metrics {"StartTime": 1679090595.5123415, "EndTime": 1679090595.5123596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5964109632703993, "count": 1, "min": 0.5964109632703993, "max": 0.5964109632703993}}}
# #metrics {"StartTime": 1679090595.5124288, "EndTime": 1679090595.512447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.34247710969712997, "count": 1, "min": 0.34247710969712997, "max": 0.34247710969712997}}}
# #metrics {"StartTime": 1679090595.5125134, "EndTime": 1679090595.5125315, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3419800069597032, "count": 1, "min": 0.3419800069597032, "max": 0.3419800069597032}}}
# #metrics {"StartTime": 1679090595.5125976, "EndTime": 1679090595.5126154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3422333558400472, "count": 1, "min": 0.3422333558400472, "max": 0.3422333558400472}}}
# #metrics {"StartTime": 1679090595.512683, "EndTime": 1679090595.5127015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3408831516901652, "count": 1, "min": 0.3408831516901652, "max": 0.3408831516901652}}}
# #metrics {"StartTime": 1679090595.5127687, "EndTime": 1679090595.512787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5823750283983019, "count": 1, "min": 0.5823750283983019, "max": 0.5823750283983019}}}
# #metrics {"StartTime": 1679090595.512854, "EndTime": 1679090595.5128727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5712012767791748, "count": 1, "min": 0.5712012767791748, "max": 0.5712012767791748}}}
# #metrics {"StartTime": 1679090595.5129392, "EndTime": 1679090595.512959, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5711635907491048, "count": 1, "min": 0.5711635907491048, "max": 0.5711635907491048}}}
# #metrics {"StartTime": 1679090595.5130258, "EndTime": 1679090595.513044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5888166851467557, "count": 1, "min": 0.5888166851467557, "max": 0.5888166851467557}}}
# #metrics {"StartTime": 1679090595.5131102, "EndTime": 1679090595.51313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5572691652509901, "count": 1, "min": 0.5572691652509901, "max": 0.5572691652509901}}}
# #metrics {"StartTime": 1679090595.5131955, "EndTime": 1679090595.5132148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5285760561625162, "count": 1, "min": 0.5285760561625162, "max": 0.5285760561625162}}}
# #metrics {"StartTime": 1679090595.5132792, "EndTime": 1679090595.5132987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5743454880184597, "count": 1, "min": 0.5743454880184597, "max": 0.5743454880184597}}}
# #metrics {"StartTime": 1679090595.5133655, "EndTime": 1679090595.5133843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5401994758182102, "count": 1, "min": 0.5401994758182102, "max": 0.5401994758182102}}}
# #metrics {"StartTime": 1679090595.5134535, "EndTime": 1679090595.5134726, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6752615610758463, "count": 1, "min": 0.6752615610758463, "max": 0.6752615610758463}}}
# #metrics {"StartTime": 1679090595.5135405, "EndTime": 1679090595.5135596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6781530910068088, "count": 1, "min": 0.6781530910068088, "max": 0.6781530910068088}}}
# #metrics {"StartTime": 1679090595.513628, "EndTime": 1679090595.5136483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6757147153218587, "count": 1, "min": 0.6757147153218587, "max": 0.6757147153218587}}}
# #metrics {"StartTime": 1679090595.5137153, "EndTime": 1679090595.5137336, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6803502506679959, "count": 1, "min": 0.6803502506679959, "max": 0.6803502506679959}}}
# #metrics {"StartTime": 1679090595.513803, "EndTime": 1679090595.5138216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6876050949096679, "count": 1, "min": 0.6876050949096679, "max": 0.6876050949096679}}}
# #metrics {"StartTime": 1679090595.5138896, "EndTime": 1679090595.513908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7017442597283258, "count": 1, "min": 0.7017442597283258, "max": 0.7017442597283258}}}
# #metrics {"StartTime": 1679090595.513977, "EndTime": 1679090595.5139973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.700176207224528, "count": 1, "min": 0.700176207224528, "max": 0.700176207224528}}}
# #metrics {"StartTime": 1679090595.514064, "EndTime": 1679090595.5140831, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6784972508748373, "count": 1, "min": 0.6784972508748373, "max": 0.6784972508748373}}}
# [03/17/2023 22:03:15 INFO 140685723006784] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.5747297551896837
# [03/17/2023 22:03:15 INFO 140685723006784] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.3408831516901652
# [03/17/2023 22:03:15 INFO 140685723006784] Epoch 2: Loss improved. Updating best model
# [03/17/2023 22:03:15 INFO 140685723006784] Saving model for epoch: 2
# [03/17/2023 22:03:15 INFO 140685723006784] Saved checkpoint to "/tmp/tmpafjxv3qj/mx-mod-0000.params"
# [03/17/2023 22:03:15 INFO 140685723006784] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1679090595.237138, "EndTime": 1679090595.527616, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 850.0, "count": 1, "min": 850, "max": 850}, "Total Batches Seen": {"sum": 29.0, "count": 1, "min": 29, "max": 29}, "Max Records Seen Between Resets": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Max Batches Seen Between Resets": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Number of Batches Since Last Reset": {"sum": 7.0, "count": 1, "min": 7, "max": 7}}}
# [03/17/2023 22:03:15 INFO 140685723006784] #throughput_metric: host=algo-1, train throughput=705.367432741174 records/second
# #metrics {"StartTime": 1679090595.8883643, "EndTime": 1679090595.8884635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5396033128102621, "count": 1, "min": 0.5396033128102621, "max": 0.5396033128102621}}}
# #metrics {"StartTime": 1679090595.888588, "EndTime": 1679090595.8886108, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5241781976487901, "count": 1, "min": 0.5241781976487901, "max": 0.5241781976487901}}}
# #metrics {"StartTime": 1679090595.8886745, "EndTime": 1679090595.888692, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.528344202041626, "count": 1, "min": 0.528344202041626, "max": 0.528344202041626}}}
# #metrics {"StartTime": 1679090595.8887439, "EndTime": 1679090595.8887582, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5033405092027452, "count": 1, "min": 0.5033405092027452, "max": 0.5033405092027452}}}
# #metrics {"StartTime": 1679090595.888804, "EndTime": 1679090595.8888192, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3332520749833849, "count": 1, "min": 0.3332520749833849, "max": 0.3332520749833849}}}
# #metrics {"StartTime": 1679090595.8888671, "EndTime": 1679090595.8888807, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.33533271418677435, "count": 1, "min": 0.33533271418677435, "max": 0.33533271418677435}}}
# #metrics {"StartTime": 1679090595.888927, "EndTime": 1679090595.888941, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3336228052775065, "count": 1, "min": 0.3336228052775065, "max": 0.3336228052775065}}}
# ...
# #metrics {"StartTime": 1679090598.9258778, "EndTime": 1679090598.9258924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3798264344533285, "count": 1, "min": 0.3798264344533285, "max": 0.3798264344533285}}}
# #metrics {"StartTime": 1679090598.9259295, "EndTime": 1679090598.9259384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.37202669779459635, "count": 1, "min": 0.37202669779459635, "max": 0.37202669779459635}}}
# #metrics {"StartTime": 1679090598.9259658, "EndTime": 1679090598.9259732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3155912902620104, "count": 1, "min": 0.3155912902620104, "max": 0.3155912902620104}}}
# #metrics {"StartTime": 1679090598.925999, "EndTime": 1679090598.926006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3159733110004001, "count": 1, "min": 0.3159733110004001, "max": 0.3159733110004001}}}
# #metrics {"StartTime": 1679090598.9260411, "EndTime": 1679090598.9260554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3155342923270332, "count": 1, "min": 0.3155342923270332, "max": 0.3155342923270332}}}
# #metrics {"StartTime": 1679090598.926089, "EndTime": 1679090598.9260974, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3160854631000095, "count": 1, "min": 0.3160854631000095, "max": 0.3160854631000095}}}
# #metrics {"StartTime": 1679090598.926123, "EndTime": 1679090598.9261305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.38889107174343535, "count": 1, "min": 0.38889107174343535, "max": 0.38889107174343535}}}
# #metrics {"StartTime": 1679090598.926155, "EndTime": 1679090598.9261622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3790689097510444, "count": 1, "min": 0.3790689097510444, "max": 0.3790689097510444}}}
# #metrics {"StartTime": 1679090598.9262016, "EndTime": 1679090598.9262173, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.39002968470255533, "count": 1, "min": 0.39002968470255533, "max": 0.39002968470255533}}}
# #metrics {"StartTime": 1679090598.9262624, "EndTime": 1679090598.9262748, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3909821457333035, "count": 1, "min": 0.3909821457333035, "max": 0.3909821457333035}}}
# #metrics {"StartTime": 1679090598.926318, "EndTime": 1679090598.9263275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.31946918434566923, "count": 1, "min": 0.31946918434566923, "max": 0.31946918434566923}}}
# #metrics {"StartTime": 1679090598.9263544, "EndTime": 1679090598.926362, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.31984263526068796, "count": 1, "min": 0.31984263526068796, "max": 0.31984263526068796}}}
# #metrics {"StartTime": 1679090598.92639, "EndTime": 1679090598.926403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.31942127015855576, "count": 1, "min": 0.31942127015855576, "max": 0.31942127015855576}}}
# #metrics {"StartTime": 1679090598.9264455, "EndTime": 1679090598.9264596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.31982771555582684, "count": 1, "min": 0.31982771555582684, "max": 0.31982771555582684}}}
# #metrics {"StartTime": 1679090598.926501, "EndTime": 1679090598.9265106, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5081969261169433, "count": 1, "min": 0.5081969261169433, "max": 0.5081969261169433}}}
# #metrics {"StartTime": 1679090598.9265368, "EndTime": 1679090598.9265442, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5084529452853732, "count": 1, "min": 0.5084529452853732, "max": 0.5084529452853732}}}
# #metrics {"StartTime": 1679090598.926573, "EndTime": 1679090598.9265862, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5077157762315538, "count": 1, "min": 0.5077157762315538, "max": 0.5077157762315538}}}
# #metrics {"StartTime": 1679090598.9266298, "EndTime": 1679090598.926639, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5085092544555664, "count": 1, "min": 0.5085092544555664, "max": 0.5085092544555664}}}
# #metrics {"StartTime": 1679090598.9266655, "EndTime": 1679090598.926673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5141858471764459, "count": 1, "min": 0.5141858471764459, "max": 0.5141858471764459}}}
# #metrics {"StartTime": 1679090598.9266984, "EndTime": 1679090598.9267116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5158551586998834, "count": 1, "min": 0.5158551586998834, "max": 0.5158551586998834}}}
# #metrics {"StartTime": 1679090598.9267578, "EndTime": 1679090598.9267733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5137092749277751, "count": 1, "min": 0.5137092749277751, "max": 0.5137092749277751}}}
# #metrics {"StartTime": 1679090598.9268248, "EndTime": 1679090598.9268405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5155711756812201, "count": 1, "min": 0.5155711756812201, "max": 0.5155711756812201}}}
# #metrics {"StartTime": 1679090598.9268851, "EndTime": 1679090598.9269, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6795010990566678, "count": 1, "min": 0.6795010990566678, "max": 0.6795010990566678}}}
# #metrics {"StartTime": 1679090598.9269636, "EndTime": 1679090598.9269774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6792406400044759, "count": 1, "min": 0.6792406400044759, "max": 0.6792406400044759}}}
# #metrics {"StartTime": 1679090598.9270341, "EndTime": 1679090598.9270484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6793034023708767, "count": 1, "min": 0.6793034023708767, "max": 0.6793034023708767}}}
# #metrics {"StartTime": 1679090598.9270787, "EndTime": 1679090598.9270911, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6792628924051921, "count": 1, "min": 0.6792628924051921, "max": 0.6792628924051921}}}
# #metrics {"StartTime": 1679090598.9271388, "EndTime": 1679090598.9271548, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6834012773301866, "count": 1, "min": 0.6834012773301866, "max": 0.6834012773301866}}}
# #metrics {"StartTime": 1679090598.927199, "EndTime": 1679090598.927214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6841351615058051, "count": 1, "min": 0.6841351615058051, "max": 0.6841351615058051}}}
# #metrics {"StartTime": 1679090598.9272583, "EndTime": 1679090598.927273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6831859058803982, "count": 1, "min": 0.6831859058803982, "max": 0.6831859058803982}}}
# #metrics {"StartTime": 1679090598.9273121, "EndTime": 1679090598.9273264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6838702413770887, "count": 1, "min": 0.6838702413770887, "max": 0.6838702413770887}}}
# [03/17/2023 22:03:18 INFO 140685723006784] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.38583148320515953
# [03/17/2023 22:03:18 INFO 140685723006784] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.3155342923270332
# [03/17/2023 22:03:18 INFO 140685723006784] Saving model for epoch: 14
# [03/17/2023 22:03:18 INFO 140685723006784] Saved checkpoint to "/tmp/tmp4tex_aqz/mx-mod-0000.params"
# [03/17/2023 22:03:18 INFO 140685723006784] Early stop condition met. Stopping training.
# [03/17/2023 22:03:18 INFO 140685723006784] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1679090598.7057817, "EndTime": 1679090598.935637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3310.0, "count": 1, "min": 3310, "max": 3310}, "Total Batches Seen": {"sum": 113.0, "count": 1, "min": 113, "max": 113}, "Max Records Seen Between Resets": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Max Batches Seen Between Resets": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 205.0, "count": 1, "min": 205, "max": 205}, "Number of Batches Since Last Reset": {"sum": 7.0, "count": 1, "min": 7, "max": 7}}}
# [03/17/2023 22:03:18 INFO 140685723006784] #throughput_metric: host=algo-1, train throughput=891.1906452338433 records/second
# [03/17/2023 22:03:18 WARNING 140685723006784] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/17/2023 22:03:18 WARNING 140685723006784] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.32097731334407154)
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('binary_classification_accuracy', 0.8682926829268293)
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('binary_f_1.000', 0.8831168831168831)
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('precision', 0.8947368421052632)
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('recall', 0.8717948717948718)
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('roc_auc_score', 0.9327894327894328)
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [03/17/2023 22:03:19 INFO 140685723006784] #train_score (algo-1) : ('binary_log_loss', 0.562256134011977)
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.32097731334407154
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.8682926829268293
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.8831168831168831
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train precision <score>=0.8947368421052632
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train recall <score>=0.8717948717948718
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9327894327894328
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [03/17/2023 22:03:19 INFO 140685723006784] #quality_metric: host=algo-1, train binary_log_loss <score>=0.562256134011977
# [03/17/2023 22:03:19 INFO 140685723006784] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [03/17/2023 22:03:19 INFO 140685723006784] Saved checkpoint to "/tmp/tmprwvrc40z/mx-mod-0000.params"
# [03/17/2023 22:03:19 INFO 140685723006784] Test data is not provided.
# #metrics {"StartTime": 1679090594.5501168, "EndTime": 1679090599.1295228, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 188.4896755218506, "count": 1, "min": 188.4896755218506, "max": 188.4896755218506}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 10.662317276000977, "count": 15, "min": 0.20456314086914062, "max": 1.3546943664550781}, "update.time": {"sum": 4135.640382766724, "count": 15, "min": 221.64273262023926, "max": 372.9267120361328}, "finalize.time": {"sum": 188.05646896362305, "count": 1, "min": 188.05646896362305, "max": 188.05646896362305}, "setuptime": {"sum": 2.4080276489257812, "count": 1, "min": 2.4080276489257812, "max": 2.4080276489257812}, "totaltime": {"sum": 4726.473808288574, "count": 1, "min": 4726.473808288574, "max": 4726.473808288574}}}
#
# 2023-03-17 22:03:37 Uploading - Uploading generated training model
# 2023-03-17 22:03:37 Completed - Training job completed
# Training seconds: 142
# Billable seconds: 142

# %% [markdown]
# Hyperparameters tuninig - tune hyperparameters (whatever you want) from XGBoost Algorithm
#
# NOTE: be careful about metrics used for evaluation. For example, for Linear Learner, the following `validation` metrics could be used: https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner-tuning.html

# %%
objective_metric_name = "validation:precision"
MAX_JOBS = 3
MAX_PARALLEL_JOBS = 4
STRATEGY = 'Bayesian'
SCALING_TYPE = 'Linear'

# %%
tuninig_job_name = "linear-learner" + strftime("%Y%m%d-%H-%M-%S", gmtime())

hyperparameter_ranges_linear = {
    "learning_rate": ContinuousParameter(0.001, 0.1, scaling_type=SCALING_TYPE),
}

tuner_linear = HyperparameterTuner(
    linear,
    objective_metric_name,
    hyperparameter_ranges_linear,
    max_jobs=MAX_JOBS,
    max_parallel_jobs=MAX_PARALLEL_JOBS,
    strategy=STRATEGY,
)

tuner_linear.fit(
    {"train": s3_input_train, "validation": s3_input_validation},
    include_cls_metadata=False,
    job_name=tuninig_job_name)
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: linear-learner20230317-22-04-00
# ......................................................!

# %% [markdown]
# Fetch all results as DataFrame

# %%
tuner = sagemaker.HyperparameterTuningJobAnalytics(tuninig_job_name)

full_df = tuner.dataframe()
full_df = full_df[full_df["FinalObjectiveValue"] > -float("inf")]
full_df
# Out:
#    learning_rate                               TrainingJobName  \
# 0       0.075426  linear-learner20230317-22-04-00-003-cedde489
# 1       0.018349  linear-learner20230317-22-04-00-002-ed7b93c6
# 2       0.001818  linear-learner20230317-22-04-00-001-59df21f3
#
#   TrainingJobStatus  FinalObjectiveValue         TrainingStartTime  \
# 0         Completed             0.742857 2023-03-17 22:05:42+00:00
# 1         Completed             0.764706 2023-03-17 22:05:45+00:00
# 2         Completed             0.793103 2023-03-17 22:05:36+00:00
#
#             TrainingEndTime  TrainingElapsedTimeSeconds
# 0 2023-03-17 22:08:04+00:00                       142.0
# 1 2023-03-17 22:08:08+00:00                       143.0
# 2 2023-03-17 22:07:58+00:00                       142.0

# %% [markdown]
# Terminate your resources

# %%
bucket_to_delete = boto3.resource('s3').Bucket(bucket_name)
bucket_to_delete.objects.all().delete()
# Out:
# [{'ResponseMetadata': {'RequestId': 'JM2QNDS28RXR17AR',
#    'HostId': 'n+SJcxe2PeHuo315s6QswdpZknLy9OhoOBG1rTxRmnvnOCd5pmEhTbMIPh7YwU78XBY2PfpTRhI=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'n+SJcxe2PeHuo315s6QswdpZknLy9OhoOBG1rTxRmnvnOCd5pmEhTbMIPh7YwU78XBY2PfpTRhI=',
#     'x-amz-request-id': 'JM2QNDS28RXR17AR',
#     'date': 'Fri, 17 Mar 2023 22:21:00 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner-2023-03-17-21-59-43-296/profiler-output/system/incremental/2023031722/1679090520.algo-1.json'},
#    {'Key': 'sagemaker/MLI-Lab_solution/train/train.csv'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner-2023-03-17-21-59-43-296/profiler-output/system/training_job_end.ts'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner-2023-03-17-21-59-43-296/profiler-output/system/incremental/2023031722/1679090580.algo-1.json'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner20230317-22-04-00-003-cedde489/output/model.tar.gz'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner-2023-03-17-21-59-43-296/profiler-output/system/incremental/2023031722/1679090460.algo-1.json'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner-2023-03-17-21-59-43-296/output/model.tar.gz'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner-2023-03-17-21-59-43-296/profiler-output/framework/training_job_end.ts'},
#    {'Key': 'sagemaker/MLI-Lab_solution/validation/validation.csv'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner20230317-22-04-00-001-59df21f3/output/model.tar.gz'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner20230317-22-04-00-002-ed7b93c6/output/model.tar.gz'},
#    {'Key': 'sagemaker/MLI-Lab_solution/output/linear-learner-2023-03-17-21-59-43-296/debug-output/training_job_end.ts'}]}]
